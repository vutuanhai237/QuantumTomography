# %%
from qoop.core import state, ansatz, metric
import qiskit
from qiskit import transpile
from qiskit.quantum_info import Operator, DensityMatrix, Kraus
from scipy.linalg import qr
import numpy as np
import tensorflow as tf

# %%
def create_kraus_operators(unitary_matrix):
    '''
        Create a set of Kraus Operators from the input unitary matrix, using QR decomposition
    '''
    kraus_ops = []
    Q, R = qr(unitary_matrix)

    #Q: a 2^N x 2^N matrix, N is the number of qubits
    for q in Q:
        q = np.expand_dims(q, 1)
        kraus_ops.append(q @ np.transpose(np.conjugate(q)))
    return tf.convert_to_tensor(kraus_ops)

def create_unitary_matrix(num_qubits: int):
    """
    Generate a random unitary matrix of size 2^n x 2^n.
    """
    dimension = 2 ** num_qubits
    # Generate a random complex matrix
    random_matrix = np.random.normal(size=(dimension, dimension)) + 1j * np.random.normal(size=(dimension, dimension))
    # Perform QR decomposition
    q, _ = qr(random_matrix)
    return q

def calculate_rho2_dephasing(input_rho, num_qubits: int, gamma: float): #for verification
    '''
    Calculate rho2 by dephasing
    '''
    
    # Convert DensityMatrix to numpy array
    rho = input_rho.data
    # Define the Pauli-Z matrix
    sigma_z = np.array([[1, 0], [0, -1]])

    # Calculate the factors
    alpha = 1 + np.sqrt(1 - gamma)
    beta = 1 - np.sqrt(1 - gamma)
    
    # n qubits => qubit thứ n => I @ I @ .... sigma_z (n) @....I
    # Loop for multiple qubits
    for i in range(num_qubits):
        # Create the tensor product of Pauli-Z matrices for all qubits
        sigma_z_i = np.eye(1)
        for j in range(num_qubits):
            if j == i:
                sigma_z_i = np.kron(sigma_z_i, sigma_z)
            else:
                sigma_z_i = np.kron(sigma_z_i, np.eye(2))
        
        # Apply the dephasing formula
        rho = alpha * rho + beta * (sigma_z_i @ rho @ sigma_z_i)
        # Normalize the density matrix (optional, depending on the context)
        rho /= np.trace(rho)

    return rho

def calculate_rho2_from_unitary(rho, unitary_matrix):
    '''
    Calculate rho' by applying U @ rho @ U(dagger)
    '''
    rho_2 = unitary_matrix  @ rho.data @ np.transpose(np.conjugate(unitary_matrix))

    return rho_2

def calculate_rho_3 (rho_2, kraus_operators):
    '''
        sum(K @ rho_2 @ K(dagger)) //rho" = rho
    '''

    rho_3 = sum(K @ rho_2 @ np.transpose(np.conjugate(K)) for K in kraus_operators)
    return rho_3

# %%
def compilation_trace_fidelity(rho, sigma):
    """Calculating the fidelity metric

    Args:
        - rho (DensityMatrix): first density matrix
        - sigma (DensityMatrix): second density matrix

    Returns:
        - float: trace metric has value from 0 to 1
    """
    rho_2 = tf.linalg.sqrtm((tf.linalg.sqrtm(rho)) @ (rho))

    # Cast to a supported type
    real_part = tf.math.real(rho_2)
    imaginary_part = tf.math.imag(rho_2)

    # Check for NaNs in both real and imaginary parts
    contains_nan_real = tf.reduce_any(tf.math.is_nan(real_part))
    contains_nan_imag = tf.reduce_any(tf.math.is_nan(imaginary_part))

    contains_nan = contains_nan_real or contains_nan_imag

    if contains_nan == True:
        rho_2 = rho

    return tf.linalg.trace(
            rho_2
            @ (tf.linalg.sqrtm(sigma))
        )
def frobenius_norm(rho, sigma):
    """
    Compute the Frobenius norm between two matrices.

    Parameters:
    rho (numpy.ndarray): The first matrix.
    sigma (numpy.ndarray): The second matrix.

    Returns:
    float: The Frobenius norm between rho and rho_prime.
    """

    # Ensure the matrices are TensorFlow tensors
    rho = tf.convert_to_tensor(rho, dtype=tf.complex128)
    sigma = tf.convert_to_tensor(sigma, dtype=tf.complex128)

    # Compute the difference between the matrices
    diff = rho - sigma

    # Compute the Frobenius norm
    #norm = tf.linalg.normalize(diff, ord='fro')
    norm = tf.sqrt(tf.reduce_sum(tf.square(diff)))
    return norm

#cost func to compare 2 given rhos
def cost(rho, rho_3):
    #return tf.square(frobenius_norm(rho, rho_3))
    return 1 - compilation_trace_fidelity(rho, rho_3)

# %%
#Auto Diff
'''
    rho: The initial rho
    unitary_matrix: randomly generated circle in initialization step
    kraus_operators: set of kraus operators
    n: number of qubits
    alpha: learning rate (?)'''
def calculate_derivative(rho, rho2, kraus_operators, num_qubits, alpha=0.1):
    tensorKraus = tf.Variable(kraus_operators)
    with tf.GradientTape() as tape:
        rho3 = calculate_rho_3(rho2, tensorKraus)
        f = cost(rho, rho3) 
    
    # Get the gradient of y with respect to x
    c = tape.gradient(f, tensorKraus)

    # Reshape c to kN * N matrix
    c = tf.reshape(c, (2**num_qubits * 2**num_qubits,2**num_qubits))

    # Reshape kraus_operators to kN * N matrix
    kraus_operators = tf.reshape(kraus_operators, (2**num_qubits * 2**num_qubits,2**num_qubits))
    
    # Compute the projection term
    proj = c - kraus_operators @ (np.transpose(np.conjugate(c)) @ kraus_operators  + np.transpose(np.conjugate(kraus_operators)) @ c) / 2

    # Update the Kraus operators
    updated_kraus_operators = kraus_operators - alpha * proj
    
    # Return the updated Kraus operators
    return updated_kraus_operators

# %%
def optimize(rho, rho2, kraus_operators, num_qubits, alpha=0.1, num_loop = 1000):
    kraus_operators_copy = tf.identity(kraus_operators)
    # try looping manually
    for i in range (0, num_loop):
        rho3 = calculate_rho_3(rho2, kraus_operators_copy)
        _cost = cost(rho, rho3) 

        #Update Kraus Operators
        kraus_operators_copy=calculate_derivative(rho, rho2, kraus_operators_copy, num_qubits, alpha)

        #Reshape
        kraus_operators_copy = tf.reshape(kraus_operators_copy, (2**num_qubits,2**num_qubits,2**num_qubits))
    
        #print('K(t)K\n',sum(K @ np.transpose(np.conjugate(K)) for K in KrausOperatorsTry)) # I

        print (_cost)
    return kraus_operators_copy

# %%
def print_check_unitary(unitary_matrix):
    print("U @ U(dagger)")
    print(unitary_matrix @ np.transpose(np.conjugate(unitary_matrix)))
        
def print_check_kraus(kraus_operators):
    print("sum( K @ K(dagger) )")
    print(sum(K @ np.transpose(np.conjugate(K)) for K in kraus_operators))

# %%
def V(num_qubits: int):
    '''
        Create a ansatz V with n qubits and assign its parameters
    '''
    #Assign random parameter
    circuit = ansatz.stargraph(num_qubits=num_qubits)
    num_params = circuit.num_parameters
    x0 = 2 * np.pi * np.random.random(num_params)
    circuit = circuit.assign_parameters(dict(zip(circuit.parameters, x0)))
    return circuit

# %%
num_qubits = 2

# Initial state |0⟩ density matrix for multiple qubits
rho = DensityMatrix.from_label('0' * num_qubits)

# Generate a random unitary_matrix and random set of kraus_operators
#unitary_matrix = create_unitary_matrix(num_qubits=num_qubits)
circuit = V(num_qubits)
# Get the unitary operator corresponding to the circuit
unitary_op = Operator(circuit)
# Get the unitary matrix
unitary_matrix = unitary_op.data
# Get first set of kraus_operators
kraus_operators = create_kraus_operators(unitary_matrix=unitary_matrix) 

#print_check_unitary(unitary_matrix=unitary_matrix)
#print_check_kraus(kraus_operators=kraus_operators)

rho2 = calculate_rho2_dephasing(rho, num_qubits, 0.3)

# %%
# Optimizing
out_kraus_operators = optimize(rho, rho2, kraus_operators, num_qubits, 0.1, 1000)
# Out:
# tf.Tensor((0.49830669807294936+0j), shape=(), dtype=complex128)
# tf.Tensor((0.4608515438676004+0j), shape=(), dtype=complex128)
# tf.Tensor((0.42535338365857434+0j), shape=(), dtype=complex128)
# tf.Tensor((0.3918390784611615+0j), shape=(), dtype=complex128)
# tf.Tensor((0.3603130481498099+0j), shape=(), dtype=complex128)
# tf.Tensor((0.33075952423686084+0j), shape=(), dtype=complex128)
# tf.Tensor((0.3031450335822271+0j), shape=(), dtype=complex128)
# tf.Tensor((0.27742099403302056+0j), shape=(), dtype=complex128)
# tf.Tensor((0.2535263174585344+0j), shape=(), dtype=complex128)
# tf.Tensor((0.23138993339817837+0j), shape=(), dtype=complex128)
# tf.Tensor((0.21093316564429698+0j), shape=(), dtype=complex128)
# tf.Tensor((0.19207191294400094+0j), shape=(), dtype=complex128)
# tf.Tensor((0.17471860243721093+0j), shape=(), dtype=complex128)
# tf.Tensor((0.15878389967403905+0j), shape=(), dtype=complex128)
# tf.Tensor((0.1441781716647077+0j), shape=(), dtype=complex128)
# tf.Tensor((0.13081270930113997+0j), shape=(), dtype=complex128)
# tf.Tensor((0.1186007227666761+0j), shape=(), dtype=complex128)
# tf.Tensor((0.10745812848263525+0j), shape=(), dtype=complex128)
# tf.Tensor((0.09730414907389984+0j), shape=(), dtype=complex128)
# tf.Tensor((0.08806174914674103+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0796579297303458+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0720239033758392+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0650951704249354+0j), shape=(), dtype=complex128)
# tf.Tensor((0.05881151509492033+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0531169379672396+0j), shape=(), dtype=complex128)
# tf.Tensor((0.04795953935674491+0j), shape=(), dtype=complex128)
# tf.Tensor((0.04329136598043071+0j), shape=(), dtype=complex128)
# tf.Tensor((0.03906823140734084+0j), shape=(), dtype=complex128)
# tf.Tensor((0.03524951899798179+0j), shape=(), dtype=complex128)
# tf.Tensor((0.031797974453909306+0j), shape=(), dtype=complex128)
# tf.Tensor((0.02867949370334477+0j), shape=(), dtype=complex128)
# tf.Tensor((0.025862910643134174+0j), shape=(), dtype=complex128)
# tf.Tensor((0.02331978823053782+0j), shape=(), dtype=complex128)
# tf.Tensor((0.02102421555568068+0j), shape=(), dtype=complex128)
# tf.Tensor((0.018952612809906233+0j), shape=(), dtype=complex128)
# tf.Tensor((0.017083545479454898+0j), shape=(), dtype=complex128)
# tf.Tensor((0.015397548620315171+0j), shape=(), dtype=complex128)
# tf.Tensor((0.013876961692792844+0j), shape=(), dtype=complex128)
# tf.Tensor((0.012505774138147796+0j), shape=(), dtype=complex128)
# tf.Tensor((0.011269481651345337+0j), shape=(), dtype=complex128)
# tf.Tensor((0.010154952931795247+0j), shape=(), dtype=complex128)
# tf.Tensor((0.009150306567522581+0j), shape=(), dtype=complex128)
# tf.Tensor((0.008244797619072153+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0074287134099021435+0j), shape=(), dtype=complex128)
# tf.Tensor((0.006693277994052282+0j), shape=(), dtype=complex128)
# tf.Tensor((0.006030564754257561+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00543341658013885+0j), shape=(), dtype=complex128)
# tf.Tensor((0.004895373083239174+0j), shape=(), dtype=complex128)
# tf.Tensor((0.004410604320618017+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00397385051925192+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0035803673178423923+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0032258760692948085+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002906518775188549+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002618817251965777+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002359636156870848+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002126149529279253+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0019158105296998018+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0017263240841752792+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0015556221658733493+0j), shape=(), dtype=complex128)
# tf.Tensor((0.001401841468297027+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0012633032457018967+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0011384951159778556+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0010260546395057801+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0009247545043002958+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0008334891632568731+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0007512627835570829+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006771783812653531+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000610428026103893+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005502840122125763+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004960909006304082+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004472583482155734+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00040325464591828286+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003636008967432547+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003278657704760546+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00029566077837184235+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00026663601649501434+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002404763314576286+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002168978667809185+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001956449522365622+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001764873021899982+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00015921749234981686+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00014364868728167224+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00012961259384902668+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011695761812291483+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010554720557121033+0j), shape=(), dtype=complex128)
# tf.Tensor((9.525834631607388e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.598022905859093e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.761302888242838e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.006681564214468e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.326057092498338e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.712130279744709e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.158324861320729e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.658715710137429e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.207964186797586e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.80125991880087e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.4342683700283594e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.1030836232126546e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8041858576743905e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5344030538665407e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2908765052509494e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0710297571890912e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8725406332409378e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.693316040285442e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5314692772161465e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3852995968122173e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2532737975745611e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1340096433443136e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0262609285160984e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.289040254212289e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.409257670094483e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.6141253081418725e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((6.895404059292787e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((6.245663348170005e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((5.658201329916679e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((5.126973000035839e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((4.6465254153194024e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((4.2119393428574625e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((3.818776675212909e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((3.4630330565388334e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((3.141095190950516e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8497023776274943e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((2.585911845986999e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((2.347067515229284e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1307718420793265e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9348604501923106e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((1.757379259226255e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5965638752168942e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4508210084418494e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3187117288149253e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1989363645215079e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((1.090320892460639e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.918046668389024e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((9.024293561310515e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((8.213289633962617e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((7.477208324724316e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((6.80897535132452e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((6.202195531601618e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((5.651086811830908e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((5.150420741006911e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((4.6954687549227714e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((4.281953794871285e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((3.9060065548657263e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((3.5641260931473795e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((3.253144224002469e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9701934678438846e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7126780088870817e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((2.478247604909001e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2647739439385361e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0703293657220456e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8931676026845423e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7317064060495824e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5845118894741717e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4502843537211874e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.327845442489206e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2161266693677675e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1141589306706834e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0210630529972065e-07+0j), shape=(), dtype=complex128)
# tf.Tensor((9.360413100178988e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((8.583697042041649e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((7.873909901867648e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((7.225083942241639e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((6.631799176481934e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((6.089131987518925e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((5.5926084430169e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((5.138162317841477e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((4.722097002307635e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((4.341050929834722e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((3.991966690541915e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((3.6720623874941793e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((3.378806434639614e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((3.109894308739314e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8632276216633556e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((2.636895068963696e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4291550881905266e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((2.23842127056173e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0632469621695293e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.902313062629446e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7544165009653057e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6184594220369775e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4934400383026514e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.37844369252349e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2726351084069165e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1752513295881784e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0855950804966596e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0030290931162256e-08+0j), shape=(), dtype=complex128)
# tf.Tensor((9.269706779946318e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((8.568868947733677e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((7.922901112955572e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((7.32734106723143e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((6.778104078009051e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((6.271448915740052e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((5.803947544791299e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((5.372460254449152e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((4.974107681299245e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((4.606251824412766e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((4.266470954306101e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((3.952542959595462e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((3.6624308030752672e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((3.394261982592184e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((3.1463177618817895e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9170197368699746e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7049164019743444e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((2.508674157297719e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3270670945763072e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1589671161947876e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0033372738481603e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8592204442668958e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7257397733061453e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6020844650910249e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.487508560771289e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3813263866069292e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2829030060501623e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1916554409907576e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1070460104178892e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0285770013496176e-09+0j), shape=(), dtype=complex128)
# tf.Tensor((9.557911129220997e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((8.882645730068361e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((8.256080263890908e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((7.674604285412556e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((7.134891566451529e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((6.63386345856054e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((6.168686672580748e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((5.736722208382616e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((5.335549779772464e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((4.962920074902399e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((4.6167536460473e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((4.2951386891587617e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((3.9962899656131867e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((3.7185599044420314e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((3.460428610324584e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((3.2204827693504967e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9974223103579334e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((2.790023767573757e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((2.597176917973343e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((2.417840372359592e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2510460162550316e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((2.095901230347863e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9515877802689374e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8173285099010172e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6924128765083424e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5761814076142855e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4680190396632042e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3673595589125398e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2736756094255952e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.186474252179437e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1053091775181656e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0297418473470543e-10+0j), shape=(), dtype=complex128)
# tf.Tensor((9.593947858377305e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((8.938949580539202e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((8.329015255270633e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((7.761113973714373e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((7.232237031473687e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((6.739730995519722e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((6.280986841744607e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((5.853717510717615e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((5.455758067540728e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((5.084999088467157e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((4.739664216657502e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((4.4179104818908854e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((4.118150265242093e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((3.838862561167389e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((3.5786040797347596e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((3.336153575617118e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((3.11018988341516e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8996582912554913e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7034374738832412e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5205726394972316e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3501200985265314e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1912360814724252e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((2.043198943368907e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9051760169475074e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.776556679544683e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.656652592885166e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5448531343054128e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4406587034443419e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.343525291019887e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2529199899802279e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.168454222266746e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0897283075905762e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((1.016375872353592e-11+0j), shape=(), dtype=complex128)
# tf.Tensor((9.478862139644662e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((8.841372078904897e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((8.24618151540335e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((7.691514092300622e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((7.1740391405228365e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((6.6915362140207435e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((6.24167384444263e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((5.821898518831858e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((5.430766947256416e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((5.065503572154739e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((4.725442259712054e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((4.4080294969717215e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((4.112155060909117e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((3.836153616987303e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((3.5786928975767296e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3384406350478457e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((3.1142866063760266e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((2.905564677746497e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7103874700173947e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5286439608862565e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((2.35889086042107e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((2.201017146319373e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0534685063466895e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.91580085129317e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7873480473440395e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6676660052894476e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5558665467096944e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4517276269998547e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.354694134647616e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2635448243258907e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1787237852445287e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.100008972798605e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0268452754758073e-12+0j), shape=(), dtype=complex128)
# tf.Tensor((9.580114479490476e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((8.936185125207885e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((8.3366646919103e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((7.782663402622347e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((7.261968804073149e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((6.77347067323808e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((6.321609902215641e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((5.898614929833457e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((5.500044863993026e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((5.134781488891349e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((4.79061235125755e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((4.468647674116255e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((4.1733283495659634e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((3.8957725934096743e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((3.6359804056473877e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((3.391731340229853e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((3.163025397157071e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9543034685275416e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((2.758904216193514e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((2.569056078982612e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((2.398081733190338e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((2.241540286718191e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0905499553691698e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9484414082171497e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.821875983409882e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6964207816272392e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5842882561400984e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4799272918253337e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3811174426336947e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.290079154614432e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2045919817182948e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1224354778960333e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0480505352461478e-13+0j), shape=(), dtype=complex128)
# tf.Tensor((9.758860386455126e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((9.092726571680032e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((8.548717289613705e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((7.949196856316121e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((7.394085344003543e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((6.927791673660977e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((6.439293542825908e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((6.039613253960852e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((5.595524044110789e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((5.262457136723242e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((4.851674617611934e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((4.5630166312093934e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((4.2743586448068527e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((3.952393967665557e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((3.708144902248023e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((3.47499806707674e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((3.197442310920451e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9976021664879227e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((2.808864252301646e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((2.631228568361621e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((2.475797344914099e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2426505097428162e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1094237467877974e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9761969838327786e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8540724511240114e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7430501486614958e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.63202784619898e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4654943925052066e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3655743202889425e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2878587085651816e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2101430968414206e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1324274851176597e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0658141036401503e-14+0j), shape=(), dtype=complex128)
# tf.Tensor((9.880984919163893e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((9.325873406851315e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((8.659739592076221e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((8.215650382226158e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((7.771561172376096e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((7.327471962526033e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((6.8833827526759706e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((5.773159728050814e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((5.329070518200751e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((5.10702591327572e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((4.773959005888173e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((4.440892098500626e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((4.107825191113079e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((3.774758283725532e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((3.552713678800501e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((3.219646771412954e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9976021664879227e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9976021664879227e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7755575615628914e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((2.55351295663786e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3314683517128287e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1094237467877974e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9984014443252818e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7763568394002505e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6653345369377348e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5543122344752192e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4432899320127035e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3322676295501878e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2212453270876722e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-15+0j), shape=(), dtype=complex128)
# tf.Tensor((9.992007221626409e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((8.881784197001252e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((9.992007221626409e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((9.992007221626409e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((8.881784197001252e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((7.771561172376096e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((7.771561172376096e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((7.771561172376096e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((7.771561172376096e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((6.661338147750939e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((6.661338147750939e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((6.661338147750939e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((6.661338147750939e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((5.551115123125783e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((5.551115123125783e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((5.551115123125783e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((4.440892098500626e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3306690738754696e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3306690738754696e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3306690738754696e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3306690738754696e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3306690738754696e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3306690738754696e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((1.1102230246251565e-16+0j), shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor(0j, shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)
# tf.Tensor((-2.220446049250313e-16+0j), shape=(), dtype=complex128)

# %%
print(1 - cost(rho, calculate_rho_3(rho2, out_kraus_operators)))

#K(dagger)
# Out:
# tf.Tensor((1.0000000000000002+0j), shape=(), dtype=complex128)

# %%
print(calculate_rho_3(rho2, out_kraus_operators))
# Out:
# tf.Tensor(
# [[ 1.00000000e+00+0.j  1.28616040e-16+0.j -1.31656262e-16+0.j
#   -1.09165996e-16+0.j]
#  [ 1.28616040e-16+0.j  1.63344651e-31+0.j -1.18790105e-31+0.j
#   -1.10761184e-31+0.j]
#  [-1.31656262e-16+0.j -1.18790105e-31+0.j  1.59461077e-31+0.j
#    1.11822637e-31+0.j]
#  [-1.09165996e-16+0.j -1.10761184e-31+0.j  1.11822637e-31+0.j
#    1.98242658e-31+0.j]], shape=(4, 4), dtype=complex128)

# %%
print(out_kraus_operators)
# Out:
# tf.Tensor(
# [[[ 4.97014282e-01+0.j  2.77008580e-01+0.j  2.21489539e-01+0.j
#     2.49145000e-01+0.j]
#   [-1.80304134e-16+0.j  2.87406982e-01+0.j  2.46321120e-01+0.j
#     2.66850785e-01+0.j]
#   [-3.14904654e-17+0.j  2.51181224e-01+0.j  2.15396637e-01+0.j
#     2.33276761e-01+0.j]
#   [-5.00841759e-17+0.j  2.69267434e-01+0.j  2.30838560e-01+0.j
#     2.50040280e-01+0.j]]
#
#  [[ 5.44145716e-01+0.j -2.52936768e-01+0.j  2.54873622e-01+0.j
#    -2.48567687e-01+0.j]
#   [ 8.36423308e-17+0.j  2.45228135e-01+0.j -2.46461760e-01+0.j
#     2.32098242e-01+0.j]
#   [-8.28506075e-17+0.j -2.46289157e-01+0.j  2.47528301e-01+0.j
#    -2.33104931e-01+0.j]
#   [ 2.08508081e-16+0.j  2.29742412e-01+0.j -2.30900714e-01+0.j
#     2.17476705e-01+0.j]]
#
#  [[ 4.54966547e-01+0.j  2.43511419e-01+0.j -2.41865086e-01+0.j
#    -2.48627185e-01+0.j]
#   [ 3.50937877e-16+0.j  2.52395684e-01+0.j -2.51165154e-01+0.j
#    -2.66669128e-01+0.j]
#   [-3.47929159e-16+0.j -2.51303552e-01+0.j  2.50078461e-01+0.j
#     2.65517446e-01+0.j]
#   [-3.87878554e-16+0.j -2.69326125e-01+0.j  2.68015151e-01+0.j
#     2.84597493e-01+0.j]]
#
#  [[ 4.99887672e-01+0.j -2.21714431e-01+0.j -2.77525009e-01+0.j
#     2.49146913e-01+0.j]
#   [ 2.61081861e-17+0.j  2.15250144e-01+0.j  2.51042204e-01+0.j
#    -2.32269708e-01+0.j]
#   [ 1.74787026e-16+0.j  2.46147973e-01+0.j  2.87243833e-01+0.j
#    -2.65698835e-01+0.j]
#   [-4.25304717e-17+0.j -2.29680182e-01+0.j -2.67956318e-01+0.j
#     2.47885693e-01+0.j]]], shape=(4, 4, 4), dtype=complex128)
