# %%
from qoop.core import state, ansatz, metric
import qiskit
from qiskit import transpile
from qiskit.quantum_info import Operator, DensityMatrix, Kraus
from scipy.linalg import qr
import numpy as np
import tensorflow as tf

# %%
# Step 1: Read quantum compilation and learn how to use qoop
# https://github.com/vutuanhai237/qoop/wiki/Advance:-Custom-state-preparation

# Step 2: Implement the following function

def V(num_qubits: int):
    '''
        Create a ansatz V with n qubits and assign its parameters
    '''
    #Assign random parameter
    circuit = ansatz.stargraph(num_qubits=num_qubits)
    num_params = circuit.num_parameters
    x0 = 2 * np.pi * np.random.random(num_params)
    circuit = circuit.assign_parameters(dict(zip(circuit.parameters, x0)))
    return circuit

# def Epsilon(rho, kraus_operators):
#     # K = K_noise = [\sqrt(p) I @ I, \sqrt(1-p) Z @ Z]
#     # see Eq. 1 Ref. [1]
#     return sum(K @ rho.data @ np.transpose(np.conjugate(K)) for K in kraus_operators)

# def Epsilon2(rho, unitary_matrix):
#     # K = K_noise = [\sqrt(p) I @ I, \sqrt(1-p) Z @ Z]
#     # see Eq. 1 Ref. [1]
#     return (np.transpose(np.conjugate(unitary_matrix)) @ rho.data @ unitary_matrix)

def calculate_rho_3 (rho, unitary_matrix, kraus_operators):
    '''
        rho -E(rho) = U @ rho @ U(dagger)-> rho' -> U(dagger) @ U @ rho @ U(dagger) @ U -> rho
        sum(K @ U @ rho @ U(dagger) @ K(dagger)) //rho'' = rho
    '''
    rho_2 = unitary_matrix  @ rho @ np.transpose(np.conjugate(unitary_matrix))
    rho_3 = sum(K @ rho_2 @ np.transpose(np.conjugate(K)) for K in kraus_operators)
    return rho_3

def create_kraus_operators(unitary_matrix):
    '''
        Create a set of Kraus Operators from the input unitary matrix, using QR decomposition
    '''
    kraus_ops = []
    Q, R = qr(unitary_matrix)

    #Q: a 2^N x 2^N matrix, N is the number of qubits
    for q in Q:
        q = np.expand_dims(q, 1)
        kraus_ops.append(q @ np.transpose(np.conjugate(q)))
    return tf.convert_to_tensor(kraus_ops)

def compilation_trace_fidelity(rho, sigma):
    """Calculating the fidelity metric

    Args:
        - rho (DensityMatrix): first density matrix
        - sigma (DensityMatrix): second density matrix

    Returns:
        - float: trace metric has value from 0 to 1
    """
    rho_2 = tf.linalg.sqrtm((tf.linalg.sqrtm(rho)) @ (rho))

    # Cast to a supported type
    real_part = tf.math.real(rho_2)
    imaginary_part = tf.math.imag(rho_2)

    # Check for NaNs in both real and imaginary parts
    contains_nan_real = tf.reduce_any(tf.math.is_nan(real_part))
    contains_nan_imag = tf.reduce_any(tf.math.is_nan(imaginary_part))

    contains_nan = contains_nan_real or contains_nan_imag

    if contains_nan == True:
        rho_2 = rho

    return tf.linalg.trace(
            rho_2
            @ (tf.linalg.sqrtm(sigma))
        )

def frobenius_norm(rho, sigma):
    """
    Compute the Frobenius norm between two matrices.

    Parameters:
    rho (numpy.ndarray): The first matrix.
    sigma (numpy.ndarray): The second matrix.

    Returns:
    float: The Frobenius norm between rho and rho_prime.
    """

    # Ensure the matrices are TensorFlow tensors
    rho = tf.convert_to_tensor(rho, dtype=tf.complex128)
    sigma = tf.convert_to_tensor(sigma, dtype=tf.complex128)

    # Compute the difference between the matrices
    diff = rho - sigma

    # Compute the Frobenius norm
    #norm = tf.linalg.normalize(diff, ord='fro')
    norm = tf.sqrt(tf.reduce_sum(tf.square(diff)))
    return norm

#cost func to compare 2 given rhos
def cost(rho, rho_3):
    return tf.square(frobenius_norm(rho, rho_3))

# %%
n = 3

#Create a ansatz V with N qubits
circuit = V(n)

print(circuit)
# Out:
#      ┌────────────┐   ┌────────────┐
# q_0: ┤ Ry(2.1819) ├─■─┤ Ry(3.4218) ├─■─
#      ├────────────┤ │ └────────────┘ │
# q_1: ┤ Ry(4.7851) ├─■────────────────┼─
#      ├────────────┤                  │
# q_2: ┤ Ry(4.6374) ├──────────────────■─
#      └────────────┘

# %%
# Get the unitary operator corresponding to the circuit
unitary_op = Operator(circuit)

# Get the unitary matrix
unitary_matrix = unitary_op.data

print (unitary_matrix) #2^N x 2^N
# Out:
# [[-0.46959889+0.j -0.1659604 +0.j -0.43662844+0.j -0.15430835+0.j
#   -0.5062228 +0.j -0.17890361+0.j -0.470681  +0.j -0.16634282+0.j]
#  [ 0.1659604 +0.j -0.46959889+0.j  0.15430835+0.j -0.43662844+0.j
#    0.17890361+0.j -0.5062228 +0.j  0.16634282+0.j -0.470681  +0.j]
#  [-0.37691838+0.j -0.26905018+0.j  0.40538003+0.j  0.28936655+0.j
#   -0.40631416+0.j -0.29003334+0.j  0.43699553+0.j  0.31193418+0.j]
#  [-0.26905018+0.j  0.37691838+0.j  0.28936655+0.j -0.40538003+0.j
#   -0.29003334+0.j  0.40631416+0.j  0.31193418+0.j -0.43699553+0.j]
#  [ 0.5062228 +0.j  0.17890361+0.j  0.470681  +0.j  0.16634282+0.j
#   -0.46959889+0.j -0.1659604 +0.j -0.43662844+0.j -0.15430835+0.j]
#  [ 0.17890361+0.j -0.5062228 +0.j  0.16634282+0.j -0.470681  +0.j
#   -0.1659604 +0.j  0.46959889+0.j -0.15430835+0.j  0.43662844+0.j]
#  [ 0.40631416+0.j  0.29003334+0.j -0.43699553+0.j -0.31193418+0.j
#   -0.37691838+0.j -0.26905018+0.j  0.40538003+0.j  0.28936655+0.j]
#  [-0.29003334+0.j  0.40631416+0.j  0.31193418+0.j -0.43699553+0.j
#    0.26905018+0.j -0.37691838+0.j -0.28936655+0.j  0.40538003+0.j]]

# %%
# Initialize a set of Kraus Operators from the given circuit
kraus_operators = create_kraus_operators(unitary_matrix=unitary_matrix)

#print(sum(K @ np.transpose(np.conjugate(K)) for K in KrausOperators))
print(unitary_matrix @ np.transpose(np.conjugate(unitary_matrix)))
# Out:
# [[ 1.00000000e+00+0.j  4.07180401e-18+0.j  3.23323957e-17+0.j
#   -4.26947040e-17+0.j -3.69634617e-17+0.j -8.65534487e-17+0.j
#    2.06930124e-17+0.j  1.83776684e-17+0.j]
#  [ 4.07180401e-18+0.j  1.00000000e+00+0.j -2.32582146e-17+0.j
#   -2.12821065e-17+0.j -8.04095687e-17+0.j  4.01809378e-17+0.j
#   -2.88083898e-17+0.j  2.99009004e-17+0.j]
#  [ 3.23323957e-17+0.j -2.32582146e-17+0.j  1.00000000e+00+0.j
#   -5.94563417e-18+0.j -4.59946040e-17+0.j -2.71507204e-17+0.j
#    6.72592452e-18+0.j -2.64786903e-17+0.j]
#  [-4.26947040e-17+0.j -2.12821065e-17+0.j -5.94563417e-18+0.j
#    1.00000000e+00+0.j -1.05194314e-17+0.j -1.84083755e-17+0.j
#   -4.30699040e-17+0.j -5.43201927e-17+0.j]
#  [-3.69634617e-17+0.j -8.04095687e-17+0.j -4.59946040e-17+0.j
#   -1.05194314e-17+0.j  1.00000000e+00+0.j  5.09092819e-18+0.j
#   -4.71672949e-19+0.j  4.27653553e-17+0.j]
#  [-8.65534487e-17+0.j  4.01809378e-17+0.j -2.71507204e-17+0.j
#   -1.84083755e-17+0.j  5.09092819e-18+0.j  1.00000000e+00+0.j
#    3.26921426e-17+0.j  4.58941462e-18+0.j]
#  [ 2.06930124e-17+0.j -2.88083898e-17+0.j  6.72592452e-18+0.j
#   -4.30699040e-17+0.j -4.71672949e-19+0.j  3.26921426e-17+0.j
#    1.00000000e+00+0.j  9.22560189e-18+0.j]
#  [ 1.83776684e-17+0.j  2.99009004e-17+0.j -2.64786903e-17+0.j
#   -5.43201927e-17+0.j  4.27653553e-17+0.j  4.58941462e-18+0.j
#    9.22560189e-18+0.j  1.00000000e+00+0.j]]

# %%
#Initialize rho
rho = DensityMatrix.from_label('0' * n)
rho = tf.convert_to_tensor(rho)

#calculate rho_3
rho_3 = calculate_rho_3(rho=rho, kraus_operators=kraus_operators, unitary_matrix=unitary_matrix) 

#print(rho)
#print(rho3)

# %%
print(cost(rho=rho, rho_3=rho_3))
# Out:
# tf.Tensor((1.0994815861721623+0j), shape=(), dtype=complex128)

# %%
# Step 3: Implement the following function
# state_need_tomogaphy = ...
# rho = np.conjugate(np.transpose(state_need_tomogaphy)) @ state_need_tomogaphy   # density matrix
# rho' = Delta(rho)
# compiler = qoop.qcompilation.QuantumCompilation(U = rho', V = V())
# compiler.fit()
# compiler.plot()
# see fidelities versus iteration

# %%
#Auto Diff
'''
    rho: The initial rho
    unitary_matrix: randomly generated circle in initialization step
    kraus_operators: set of kraus operators
    n: number of qubits
    alpha: learning rate (?)'''
def calculate_derivative(rho, unitary_matrix, kraus_operators, n, alpha=0.1):
    tensorKraus = tf.Variable(kraus_operators)
    with tf.GradientTape() as tape:
        y = calculate_rho_3(rho, unitary_matrix, tensorKraus)
        f = cost(rho, y) 
    
    # Get the gradient of y with respect to x
    c = tape.gradient(f, tensorKraus)

    # Reshape c to kN * N matrix
    c = tf.reshape(c, (2**n * 2**n,2**n))

    # Reshape kraus_operators to kN * N matrix
    kraus_operators = tf.reshape(kraus_operators, (2**n * 2**n,2**n))
    
    # Compute the projection term
    proj = c - kraus_operators @ (np.transpose(np.conjugate(c)) @ kraus_operators  + np.transpose(np.conjugate(kraus_operators)) @ c) / 2

    # Update the Kraus operators
    updated_kraus_operators = kraus_operators - alpha * proj
    
    # Return the updated Kraus operators
    return updated_kraus_operators

# %%
kraus_operators_copy = tf.identity(kraus_operators)

# %%
# try looping manually
for i in range (0, 1000):
    _cost = cost(rho, calculate_rho_3(rho, unitary_matrix, kraus_operators_copy))

    #Update Kraus Operators
    kraus_operators_copy=calculate_derivative(rho, unitary_matrix, kraus_operators_copy, n)

    #Reshape
    kraus_operators_copy = tf.reshape(kraus_operators_copy, (2**n,2**n,2**n))
    
    #print('K(t)K\n',sum(K @ np.transpose(np.conjugate(K)) for K in KrausOperatorsTry)) # I

    print (_cost)
# Out:
# tf.Tensor((1.0994815861721623+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0119524331103875+0j), shape=(), dtype=complex128)
# tf.Tensor((0.9078986778469077+0j), shape=(), dtype=complex128)
# tf.Tensor((0.7901033452423137+0j), shape=(), dtype=complex128)
# tf.Tensor((0.6647949205062709+0j), shape=(), dtype=complex128)
# tf.Tensor((0.5406572338008884+0j), shape=(), dtype=complex128)
# tf.Tensor((0.4264429558439135+0j), shape=(), dtype=complex128)
# tf.Tensor((0.3284170040569295+0j), shape=(), dtype=complex128)
# tf.Tensor((0.24911618563764562+0j), shape=(), dtype=complex128)
# tf.Tensor((0.18781154207641415+0j), shape=(), dtype=complex128)
# tf.Tensor((0.1418753983991013+0j), shape=(), dtype=complex128)
# tf.Tensor((0.10808697517622433+0j), shape=(), dtype=complex128)
# tf.Tensor((0.08343672727450809+0j), shape=(), dtype=complex128)
# tf.Tensor((0.06545721879159548+0j), shape=(), dtype=complex128)
# tf.Tensor((0.05226780297597941+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0424943008496498+0j), shape=(), dtype=complex128)
# tf.Tensor((0.03515632932474067+0j), shape=(), dtype=complex128)
# tf.Tensor((0.02956304193013236+0j), shape=(), dtype=complex128)
# tf.Tensor((0.025229915913770818+0j), shape=(), dtype=complex128)
# tf.Tensor((0.02181695392571053+0j), shape=(), dtype=complex128)
# tf.Tensor((0.019084546479705825+0j), shape=(), dtype=complex128)
# tf.Tensor((0.016862625626989373+0j), shape=(), dtype=complex128)
# tf.Tensor((0.015029356998521324+0j), shape=(), dtype=complex128)
# tf.Tensor((0.01349649902756454+0j), shape=(), dtype=complex128)
# tf.Tensor((0.012199354678557891+0j), shape=(), dtype=complex128)
# tf.Tensor((0.011089862622641937+0j), shape=(), dtype=complex128)
# tf.Tensor((0.010131827921173845+0j), shape=(), dtype=complex128)
# tf.Tensor((0.009297610738738303+0j), shape=(), dtype=complex128)
# tf.Tensor((0.008565810854948359+0j), shape=(), dtype=complex128)
# tf.Tensor((0.007919634930434155+0j), shape=(), dtype=complex128)
# tf.Tensor((0.007345734358312165+0j), shape=(), dtype=complex128)
# tf.Tensor((0.006833369551215752+0j), shape=(), dtype=complex128)
# tf.Tensor((0.006373802358141424+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0059598492434626135+0j), shape=(), dtype=complex128)
# tf.Tensor((0.005585548792922756+0j), shape=(), dtype=complex128)
# tf.Tensor((0.005245911325487424+0j), shape=(), dtype=complex128)
# tf.Tensor((0.004936728085560522+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0046544241388005725+0j), shape=(), dtype=complex128)
# tf.Tensor((0.004395943681759114+0j), shape=(), dtype=complex128)
# tf.Tensor((0.004158659661537352+0j), shape=(), dtype=complex128)
# tf.Tensor((0.003940301830940333+0j), shape=(), dtype=complex128)
# tf.Tensor((0.003738898936995913+0j), shape=(), dtype=complex128)
# tf.Tensor((0.003552731859270834+0j), shape=(), dtype=complex128)
# tf.Tensor((0.003380295317346919+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0032202663486178246+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0030714781832347233+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0029328984575436833+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002803610942051582+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0026828001368156247+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002569738221715255+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002463773952406297+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002364323172839062+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0022708606778077344+0j), shape=(), dtype=complex128)
# tf.Tensor((0.002182913208308957+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0021000534016332698+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0020218945494098473+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0019480860420119123+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0018783093981253366+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0018122747948903467+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0017497180276221799+0j), shape=(), dtype=complex128)
# tf.Tensor((0.001690397839301479+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0016340935692675618+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0015806030782191513+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0015297409130184635+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0014813366801402128+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0014352336010934655+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0013912872269221132+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0013493642920807867+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0013093416906869776+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0012711055604470772+0j), shape=(), dtype=complex128)
# tf.Tensor((0.001234550461511319+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0011995786391841502+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0011660993608487917+0j), shape=(), dtype=complex128)
# tf.Tensor((0.001134028318692466+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0011032870908774838+0j), shape=(), dtype=complex128)
# tf.Tensor((0.001073802654713919+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0010455069461783087+0j), shape=(), dtype=complex128)
# tf.Tensor((0.001018336460804928+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000992231891568393+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0009671377998910462+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0009430023163576115+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0009197768681105509+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0008974159302422869+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0008758767988002109+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0008551193832833171+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0008351060167409499+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0008158012817873953+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0007971718510256702+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0007791863405325195+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0007618151751966834+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000745030464826879+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0007288058900558664+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000713116597165186+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006979391010419169+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006832511955565591+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006690318707202243+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006552612360410736+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006419204495552864+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006289916520572108+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006164579060976569+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0006043031393592378+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005925120920531679+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005810702680143586+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005699638892003286+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005591798533257438+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000548705694387938+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005385295458598953+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005286401063466647+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00051902660751825+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005096787841482942+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0005005868461016023+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004917414521270793+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00048313368532407983+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00047475503016115606+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00046659735093577915+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00045865287157271665+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00045091415666666853+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004433740936822653+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00043602587623136306+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004288629883536959+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000421879189732545+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004150685017823835+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004084251945502387+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0004019437743765713+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00039561897226598146+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00038944573292116775+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003834192043973849+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003775347283374256+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003717878307503172+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003661742132991862+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003606897450665588+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00035533045476723873+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00035009252338126035+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00034497227718118456+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00033996618112962777+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00033507083262493756+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00033028295557397823+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003255993947726331+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003210171105760146+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00031653317384118236+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003121447611267831+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00030784915013461504+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0003036437153793662+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000299525924073482+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002954933322150736+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002915435808674737+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002876743926197117+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00028388356821801584+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00028016898335886896+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00027652858563482254+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00027296039162487396+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00026946248412146795+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00026603300948707426+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00026267017513315527+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00025937224711540026+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00025613754783884203+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00025296445386737646+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002498513938321331+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002467968464336995+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00024379933853339186+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002408574433290342+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002379697786110647+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002351350050948297+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00023235182482539153+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00022961897965121023+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00022693524976332354+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002242994522968134+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002217104399915922+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0002191670999095498+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00021666835220548626+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00021421314894915652+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00021180047299607278+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00020942933690472815+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00020709878189811346+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00020480787686741399+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00020255571741600723+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00020034142494181024+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001981641457563281+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00019602305023864484+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00019391733202284823+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00019184620721732549+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00018980891365458276+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00018780471017012962+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00018583287590923512+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001838927096602974+0j), shape=(), dtype=complex128)
# tf.Tensor((0.000181983529213625+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001801046707446183+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00017825548822019744+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001764353528275263+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001746436524240989+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00017287979100820934+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00017114318820905642+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00016943327879549667+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001677495122028467+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00016609135207684497+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00016445827583411445+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00016284977423844003+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001612653509922598+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00015970452234263265+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001581668167012303+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001566517742776931+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001551589467258589+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001536878968023196+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00015223819803685554+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00015080943441425485+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001494012000670477+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00014801309897874413+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00014664474469724904+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00014529576005786006+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00014396577691570453+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00014265443588711767+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001413613860996255+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00014008628495027002+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013882879787191266+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013758859810720283+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013636536648999444+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013515879123384566+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013396856772738568+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013279439833630845+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013163599221170173+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00013049306510453225+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001293653391860186+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00012825254287371246+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001271544106630372+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00012607068296416026+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001250011059439194+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00012394543137270707+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001229034164760791+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00012187482379091995+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00012085942102608038+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011985698092721501+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011886728114576575+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011789010411191164+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011692523691135071+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011597247116575712+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011503160291686914+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011410243251396976+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011318476450473604+0j), shape=(), dtype=complex128)
# tf.Tensor((0.0001122784075293108+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011138317421746282+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00011049888108879007+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010962534845580664+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010876240032986535+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010790986432975286+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010706757159300085+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010623535668963016+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010541305753845346+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010460051532569826+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010379757442595816+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010300408232536612+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010221988954692029+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010144484957790828+0j), shape=(), dtype=complex128)
# tf.Tensor((0.00010067881879934476+0j), shape=(), dtype=complex128)
# tf.Tensor((9.99216564173698e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.917322439654222e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.843338739496758e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.770201270119838e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.697897017287417e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.626413217700607e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.555737353190103e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.485857145063138e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.41676054860559e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.34843574772693e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.280871149751106e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.214055380344957e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.147977278580998e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.082625892129128e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.017990472576739e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.954060470869401e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.890825532870544e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.828275495038262e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.766400380210821e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.705190393504567e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.644635918312676e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.584727512410345e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.525455904156942e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.466811988795306e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.408786824844198e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.351371630581951e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.294557780618483e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.238336802553327e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.18270037371552e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.127640317987298e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.07314860270333e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((8.01921733562764e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.965838762006293e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.913005261689014e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.860709346324443e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.80894365662152e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.757700959677436e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.706974146370223e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.65675622881465e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.607040337878805e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.557819720759238e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.509087738615062e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.460837864257536e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.413063679893248e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.365758874922684e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.318917243789324e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.272532683878608e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.226599193466861e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.181110869716412e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.136061906719274e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.091446593584101e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.047259312569073e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((7.00349453725476e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.960146830761548e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.917210844007126e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.874681314000808e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.832553062181861e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.790820992789282e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.749480091271461e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.708525422733279e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.667952130412678e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.627755434196449e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.587930629165215e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.548473084173064e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.50937824045674e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.470641610276082e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.432258775586325e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.394225386733383e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.356537161185592e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.319189882287257e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.28217939804002e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.245501619912628e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.209152521675549e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.17312813825719e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.137424564630463e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.1020379547187463e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.066964520326236e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((6.032200530090792e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.997742308459978e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.963586234686845e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.929728741848554e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.8961663158837956e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.862895494651788e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.829912867010662e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.79721507191258e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.764798797522068e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.732660780347756e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.7007978043956036e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.669206700336555e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.6378843446938846e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.606827659044949e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.5760336092401185e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.545499204638261e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.515221497354492e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.485197581528428e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.4554245926014335e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.425899706612094e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.396620139504814e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.36758314645025e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.338786021183504e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.310226095349666e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.2819007378683985e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.25380735430532e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.225943386260571e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.198306310765269e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.170893639692469e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.143702919179117e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.1167317290575385e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.08997768230011e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.0634384244732546e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.037111633202507e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((5.010995017647275e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.985086317986245e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.959383304912951e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.933883779139159e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.908585570909506e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.883486539525119e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.8585845728743625e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.8338775869755437e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.80936352552514e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.785040359455459e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.7609060865030183e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.736958730779785e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.7131963423578755e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.6896169968578694e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.666218795047337e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.642999862444492e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.61995834893143e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.5970924283727275e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.574400298241766e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.5518801792532914e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.529530315003535e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.507348971616793e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.485334437396191e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.4634850224846534e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.441799058528021e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.42027489834685e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.3989109156132573e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.377705504533281e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.356657079534783e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.3357640749615596e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.3150249447723774e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.294438162245598e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.274002219688368e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.2537156281514635e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.233576917149435e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.213584634385111e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.193737345478384e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.1740336337012816e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.1544720997160874e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.1350513613184686e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.1157700531855946e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.096626826628255e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.0776203493463525e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.058749305189851e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.040012393923471e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.021408330994979e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((4.002935847307154e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.9845936889954806e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.9663806172063875e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.9482954078829625e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.930336851550431e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.912503753109365e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.89479493162818e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.877209220142173e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.8597454654544797e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.842402527940649e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.8251792813566896e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.808074612650222e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.791087421773868e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.774216621503301e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.757461137256277e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.740819906918247e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.72429188066495e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.7078760207935996e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.691571301554316e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.675376708983825e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.6592912407426594e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.643313905955033e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.627443725051823e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.611679729613324e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.596020962218944e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.580466476294866e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.565015335968323e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.5496666159199465e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.534419401241737e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.5192727872958335e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.504225879576186e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.489277793571813e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.474427654631593e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.459674597833673e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.445017767853806e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.430456318837838e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.415989414275771e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.401616226876859e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3873359384479606e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3731477397728424e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3590508304944084e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.3450444189963525e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.331127722290152e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.317299965900685e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.303560383755382e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.289908218074466e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.27634271926306e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.262863145804402e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.249468764155102e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.236158848642988e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.2229326813635744e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.209789552082016e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.196728758133515e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.183749604325912e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.1708514028447766e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.1580334731590176e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.145295141927607e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.132635742908932e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.1200546168699974e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.1075511114978334e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.09512458131279e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.0827743875816476e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.0704998982326396e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.0583004877729326e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.0461755372045657e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.034124433944918e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.0221465717454887e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((3.0102413506140062e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9984081767361416e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9866464623989468e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9749556259156148e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9633350915511668e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.951784289449321e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9403026555594837e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9288896315662643e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.9175446648193733e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.906267208264046e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8950567203728378e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.883912665078675e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.872834511708561e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.861821734918222e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.850873814627323e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8399902359570868e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8291704891659054e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.818414069589421e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.8077204775787804e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7970892184407243e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.786519802378347e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7760117444329122e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7655645644268167e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7551777869055905e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.744850941083701e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7345835607873602e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.7243751844020042e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.714225354817598e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.704133619375919e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.694099529818427e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.6841226422348806e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.674202517012522e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.6643387187858014e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.6545308163874038e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.644778382798588e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.6350809951028467e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.6254382344366433e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.6158496859436304e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.6063149387284407e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5968335858112466e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.587405224082255e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.578029454257892e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5687058808373186e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5594341120584646e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.550213759856682e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5410444398214658e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5319257711559096e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5228573766355302e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.5138388825677373e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.504869918752492e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4959501184426726e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.487079118305341e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.478256558383279e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.469482082058077e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4607553360117114e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4520759701903496e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.443443637768656e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4348579951122057e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4263187017442187e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4178254203094268e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.4093778165394228e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.400975559219785e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3926183201550617e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3843057741369573e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.376037598910793e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.367813475143467e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.359633086391643e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3514961190699217e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.34340226242012e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3353512084808387e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.327342652056335e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3193762906873972e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3114518246209187e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.3035689567824857e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2957273927452394e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.287926840703315e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2801670114427433e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2724476183143922e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.264768377205975e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2571290065154487e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.249529227124051e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2419687623703223e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2344473380233533e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2269646822579896e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.2195205256287353e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.212114601044658e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.20474664374528e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1974163912755405e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1901235834614382e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1828679623866484e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1756492723691895e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1684672599371748e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1613216738064597e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1542122648578185e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.147138786114534e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1401009927198654e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1330986419157213e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.126131493020291e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1191993074077338e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1123018484855537e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.1054388816750337e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0986101743899986e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0918154960166374e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0850546178930305e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.078327313289485e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.071633357389251e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.064972527268543e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0583446018772706e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.051749362020876e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.045186590340556e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0386560712954485e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.03215759114418e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.025690937926656e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0192559014461212e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.012852273251695e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.0064798466209024e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((2.000138416542398e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.993827779698747e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9875477344495987e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9812980808154362e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.975078620460426e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9688891566768718e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.962729494368364e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9565994400346862e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9504988017553407e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9444273891746603e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9383850134861207e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.932371487417075e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.926386625213585e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.920430242626777e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9145021568962162e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.908602186737004e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.9027301523250533e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8968858752823306e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.891069178663505e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8852798869417414e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.879517825995273e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8737828230939473e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8680747068850864e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8623933073811162e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8567384559459357e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.851109985282207e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8455077294189673e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8399315236978503e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8343812047616003e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8288566105412227e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8233575802440243e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8178839543415142e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8124355745567347e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8070122838535494e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.8016139264242247e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.79624034767764e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7908913942286914e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7855669138862284e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.780266755641974e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.77499076966002e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7697388072652088e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7645107209322615e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7593063642757936e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7541255920389617e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7489682600834968e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.743834225378777e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7387233459922467e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.733635481078905e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7285704908710004e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7235282366688886e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7185085808301486e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.713511386760983e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7085365189055828e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.7035838427373856e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6986532247495727e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.693744532445153e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6888576343283745e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6839923998955205e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6791486996257007e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.67432640497194e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6695253883526885e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6647455231427175e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6599866836644746e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6552487451800725e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6505315838819974e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.645835076885746e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.641159102220361e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.636503538821459e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.631868266522187e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.627253166045576e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.622658118996868e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6180830078550513e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6135277159656354e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.6089921275327247e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.604476127611496e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5999796021001905e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5955024377335574e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5910445220749243e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5866057435085944e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5821859912334806e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.577785155254983e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5734031263787863e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5690397962031012e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5646950571124885e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5603688022702057e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.556060925611953e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5517713218392983e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5474998864120635e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5432465155428583e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5390111061902323e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5347935560513948e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5305937635574235e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5264116278654275e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5222470488529212e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5180999271116813e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5139701639419174e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5098576613450072e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5057623220188696e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.5016840493513299e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.497622747414094e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4935783209575013e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4895506754039783e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4855397168431648e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4815453520254452e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4775674883567718e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4736060338932268e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4696608973354533e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4657319880225077e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4618192159277964e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4579224916527962e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4540417264217292e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4501768320768663e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4463277210732068e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4424943064728373e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4386765019407961e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.434874221739029e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4310873807219919e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4273158943317042e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4235596785928042e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4198186501075006e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4160927260512927e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.412381824167598e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.40868586276328e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4050047607045472e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.4013384374115498e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.397686812854032e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3940498075472519e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3904273425469645e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3868193394454871e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3832257203665546e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.3796464079619204e-05+0j), shape=(), dtype=complex128)
# ...
# tf.Tensor((1.259707604456154e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2566077163967456e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2535195476387885e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.25044303841908e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2473781293579077e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2443247614556749e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2412828760906995e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2382524150156656e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2352333203552833e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2322255346029196e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.229229000618041e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2262436616232463e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2232694612018505e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2203063432947219e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.21735425219744e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2144131325582935e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2114829293749468e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2085635879920291e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2056550540982122e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.2027572737242053e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1998701932396616e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1969937593505136e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1941279190970491e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1912726198507727e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1884278093122378e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1855934355082762e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1827694467900064e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1799557918299242e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1771524196198052e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1743592794681976e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1715763209980573e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1688034941444663e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1660407491520406e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1632880365729364e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1605453072644053e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1578125123868306e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1550896034008397e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1523765320656044e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1496732504365876e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1469797108631665e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1442958659863246e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1416216687369801e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.138957072333538e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1363020302797454e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1336564963628266e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1310204246508283e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.128393769491619e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1257764855095367e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1231685276044866e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1205698509492752e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1179804109879565e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1154001634333031e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1128290642658411e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1102670697308907e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1077141363373533e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1051702208553366e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1026352803144435e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.1001092720020994e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0975921534611265e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0950838824887438e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0925844171339742e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0900937156960293e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0876117367227503e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0851384390087645e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0826737815933117e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0802177237591429e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0777702250302917e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.075331245170408e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0729007441811692e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0704786823007181e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0680650200016887e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0656597179896483e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0632627372015167e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0608740388037933e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0584935841911452e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0561213349844069e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0537572530295231e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0514013003954226e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0490534393729705e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.046713632472849e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0443818424243286e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0420580321738431e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0397421648833037e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0374342039282803e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0351341128973786e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0328418555897202e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.03055739601406e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0282806983875759e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0260117271334794e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0237504468805644e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0214968224612418e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0192508189102899e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0170124014634957e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0147815355560752e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0125581868212735e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0103423210895468e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0081339043863818e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0059329029314412e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.003739283137359e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((1.0015530116081115e-05+0j), shape=(), dtype=complex128)
# tf.Tensor((9.993740551376695e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.972023807088237e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.950379554918163e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.928807468434412e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.90730722305195e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.885878496023559e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.864520966426227e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.843234315148434e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.822018224879983e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.800872380096499e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.779796467049212e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.758790173753159e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.737853189974986e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.716985207221431e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.69618591872384e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.67545501943458e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.654792206005056e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.634197176784983e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.613669631802324e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.593209272756616e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.572815803006021e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.552488927557774e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.532228353055198e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.512033787768256e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.491904941582028e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.471841525986586e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.45184325406407e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.431909840481513e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.412041001476829e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.392236454853521e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.37249591996174e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.352819117699214e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.333205770489263e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.313655602280038e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.2941683385287e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.274743706197049e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.255381433734712e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.236081251072655e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.216842889617416e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.197666082232788e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.178550563240115e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.15949606839849e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.140502334905698e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.121569101378574e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.102696107852343e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.083883095768115e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.065129807960676e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.046435988654987e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.02780138345205e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((9.009225739324533e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.990708804604644e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.972250328975832e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.95385006346601e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.935507760435098e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.917223173570979e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.898996057876687e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.880826169666926e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.862713266552252e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.844657107438827e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.82665745251476e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.80871406324533e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.790826702358858e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.77299513384721e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.755219122950321e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.73749843615301e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.71983284117433e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.702222106960921e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.684666003676896e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.667164302701424e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.649716776614555e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.632323199195518e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.61498334540904e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.597696991403767e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.580463914500298e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.563283893187007e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.54615670711071e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.52908213706812e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.512059965004737e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.495089973996495e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.47817194825769e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.461305673117437e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.444490935027181e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.427727521543484e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.41101522132524e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.394353824129436e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.377743120797141e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.361182903254974e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.344672964499742e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.328213098600823e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.311803100685006e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.295442766938467e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.279131894592097e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.262870281918553e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.246657728227766e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.230494033857991e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.214379000167851e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.198312429536068e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.182294125348548e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.166323891996124e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.15040153486625e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.13452686033928e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.118699675779858e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.102919789531655e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.087187010912819e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.071501150209308e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.055862018665934e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.040269428486321e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.024723192821303e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((8.009223125766663e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.993769042357082e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.978360758558745e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.962998091265057e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.947680858291345e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.932408878367915e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.91718197113444e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.901999957136682e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.886862657818308e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.871769895518211e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.856721493461362e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.841717275757718e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.826757067393213e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.811840694228534e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.79696798298889e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.782138761263187e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.767352857496377e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.752610100984372e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.737910321870616e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.723253351141294e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.708639020616002e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.694067162947432e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.67953761161542e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.665050200919958e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.650604765978745e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.636201142722522e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.621839167884595e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.607518679005828e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.5932395144213485e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.579001513261183e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.564804515440975e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.55064836166259e-06+0j), shape=(), dtype=complex128)
# tf.Tensor((7.536532893403452e-06+0j), shape=(), dtype=complex128)

# %%
print(sum(K @ np.transpose(np.conjugate(K)) for K in kraus_operators_copy))
print(kraus_operators_copy)
# Out:
# tf.Tensor(
# [[ 1.86909446e+00+0.j -3.15825021e-02+0.j -1.17061662e-01+0.j
#    3.71282381e-02+0.j  7.38884379e-02+0.j -2.01890225e-02+0.j
#    8.40399354e-02+0.j -2.26999877e-02+0.j]
#  [-3.15825021e-02+0.j  8.70819648e-01+0.j -1.65110657e-02+0.j
#    7.91642824e-02+0.j  4.37406550e-03+0.j -6.20787076e-02+0.j
#    1.43690868e-03+0.j -7.93502480e-02+0.j]
#  [-1.17061662e-01+0.j -1.65110657e-02+0.j  8.71547736e-01+0.j
#    2.95021555e-03+0.j  7.78549937e-02+0.j -1.92126244e-03+0.j
#    7.94108318e-02+0.j -4.72978530e-03+0.j]
#  [ 3.71282381e-02+0.j  7.91642824e-02+0.j  2.95021555e-03+0.j
#    8.60923370e-01+0.j -1.99664335e-03+0.j  7.85943154e-02+0.j
#   -4.98113512e-03+0.j  7.31783957e-02+0.j]
#  [ 7.38884379e-02+0.j  4.37406550e-03+0.j  7.78549937e-02+0.j
#   -1.99664335e-03+0.j  8.95826446e-01+0.j  3.19772850e-04+0.j
#   -9.41840828e-02+0.j  1.73477746e-02+0.j]
#  [-2.01890225e-02+0.j -6.20787076e-02+0.j -1.92126244e-03+0.j
#    7.85943154e-02+0.j  3.19772850e-04+0.j  8.81354970e-01+0.j
#    1.74593563e-02+0.j -6.73852771e-02+0.j]
#  [ 8.40399354e-02+0.j  1.43690868e-03+0.j  7.94108318e-02+0.j
#   -4.98113512e-03+0.j -9.41840828e-02+0.j  1.74593563e-02+0.j
#    8.82233162e-01+0.j  2.61011562e-03+0.j]
#  [-2.26999877e-02+0.j -7.93502480e-02+0.j -4.72978530e-03+0.j
#    7.31783957e-02+0.j  1.73477746e-02+0.j -6.73852771e-02+0.j
#    2.61011562e-03+0.j  8.71280275e-01+0.j]], shape=(8, 8), dtype=complex128)
# tf.Tensor(
# [[[ 0.26323103+0.j  0.05691306+0.j -0.16212575+0.j  0.10281429+0.j
#     0.18884223+0.j -0.11334309+0.j -0.25576907+0.j  0.10257984+0.j]
#   [ 0.07222026+0.j  0.02920941+0.j -0.07593131+0.j  0.0224952 +0.j
#     0.09001408+0.j -0.0284621 +0.j -0.07316589+0.j  0.02310078+0.j]
#   [-0.18917457+0.j -0.07700951+0.j  0.2000693 +0.j -0.05879348+0.j
#    -0.23764041+0.j  0.07491098+0.j  0.19176036+0.j -0.06001863+0.j]
#   [ 0.06670382+0.j  0.02739568+0.j -0.07102101+0.j  0.0205651 +0.j
#     0.0842121 +0.j -0.02613659+0.j -0.06768082+0.j  0.02116584+0.j]
#   [ 0.21837139+0.j  0.0899237 +0.j -0.23310259+0.j  0.06729264+0.j
#     0.27669716+0.j -0.08584441+0.j -0.22161617+0.j  0.06901133+0.j]
#   [-0.07698813+0.j -0.03197124+0.j  0.08271499+0.j -0.02354782+0.j
#    -0.09805128+0.j  0.02999089+0.j  0.07820371+0.j -0.02431461+0.j]
#   [-0.20239021+0.j -0.0844953 +0.j  0.21825075+0.j -0.06153875+0.j
#    -0.25830178+0.j  0.07811953+0.j  0.20571685+0.j -0.06401157+0.j]
#   [ 0.07187729+0.j  0.02954948+0.j -0.07659286+0.j  0.02214516+0.j
#     0.09081432+0.j -0.02814876+0.j -0.07293684+0.j  0.02280057+0.j]]
#
#  [[-0.03231945+0.j -0.04930768+0.j -0.08399594+0.j -0.11433629+0.j
#     0.09779761+0.j  0.12311499+0.j  0.02128813+0.j -0.11340213+0.j]
#   [-0.13239796+0.j  0.23709101+0.j  0.0388848 +0.j  0.17454895+0.j
#    -0.02652126+0.j -0.22468169+0.j  0.12496556+0.j  0.17784806+0.j]
#   [-0.04298783+0.j  0.07714904+0.j  0.01404782+0.j  0.05823393+0.j
#    -0.00956261+0.j -0.07529312+0.j  0.04081227+0.j  0.05856003+0.j]
#   [-0.12262694+0.j  0.22018753+0.j  0.03660688+0.j  0.16267343+0.j
#    -0.02521351+0.j -0.20926469+0.j  0.11582271+0.j  0.16569718+0.j]
#   [ 0.05024416+0.j -0.08988271+0.j -0.01555255+0.j -0.06697964+0.j
#     0.01050397+0.j  0.08650168+0.j -0.04756165+0.j -0.06771414+0.j]
#   [ 0.14202955+0.j -0.25515172+0.j -0.04265873+0.j -0.18877082+0.j
#     0.02942631+0.j  0.24284638+0.j -0.134191  +0.j -0.19218873+0.j]
#   [-0.04676607+0.j  0.08424951+0.j  0.01333511+0.j  0.06161041+0.j
#    -0.00937527+0.j -0.07892253+0.j  0.04405847+0.j  0.06328117+0.j]
#   [-0.13240281+0.j  0.23744126+0.j  0.03929955+0.j  0.17522768+0.j
#    -0.02694869+0.j -0.22549543+0.j  0.12503321+0.j  0.17846857+0.j]]
#
#  [[ 0.04750729+0.j  0.14741551+0.j  0.0589801 +0.j -0.17585888+0.j
#     0.26110905+0.j -0.04569315+0.j  0.24174544+0.j -0.17246258+0.j]
#   [ 0.12564032+0.j  0.06515222+0.j  0.12394616+0.j -0.06446265+0.j
#     0.08379891+0.j -0.08358709+0.j  0.09666173+0.j -0.06481332+0.j]
#   [ 0.19274611+0.j  0.0954845 +0.j  0.19140386+0.j -0.09359674+0.j
#     0.1218255 +0.j -0.13038568+0.j  0.14321883+0.j -0.0956947 +0.j]
#   [-0.13675048+0.j -0.06906939+0.j -0.13504406+0.j  0.06791202+0.j
#    -0.08817131+0.j  0.09139646+0.j -0.10274095+0.j  0.06861749+0.j]
#   [ 0.19130375+0.j  0.09799885+0.j  0.18790858+0.j -0.0965367 +0.j
#     0.12496059+0.j -0.12638099+0.j  0.14462183+0.j -0.09651849+0.j]
#   [-0.1370056 +0.j -0.06932955+0.j -0.13520519+0.j  0.06818827+0.j
#    -0.08847839+0.j  0.09141461+0.j -0.103     +0.j  0.06880236+0.j]
#   [ 0.20557905+0.j  0.10551631+0.j  0.20189311+0.j -0.10398639+0.j
#     0.13460818+0.j -0.13573871+0.j  0.15566691+0.j -0.10391252+0.j]
#   [-0.14755344+0.j -0.07441092+0.j -0.14566922+0.j  0.0731299 +0.j
#    -0.09490154+0.j  0.09856572+0.j -0.1106361 +0.j  0.07386672+0.j]]
#
#  [[ 0.13920324+0.j -0.13346042+0.j  0.14318103+0.j  0.1558989 +0.j
#     0.00196797+0.j  0.06545518+0.j  0.02938401+0.j  0.15690657+0.j]
#   [-0.07077165+0.j  0.13257007+0.j -0.08992161+0.j -0.13546317+0.j
#    -0.14174734+0.j -0.16086959+0.j -0.14386846+0.j -0.14048062+0.j]
#   [ 0.05405445+0.j -0.10116487+0.j  0.06800122+0.j  0.10333239+0.j
#     0.10938278+0.j  0.1247537 +0.j  0.11052332+0.j  0.1079092 +0.j]
#   [ 0.07705371+0.j -0.14318895+0.j  0.09774731+0.j  0.14654449+0.j
#     0.15130691+0.j  0.17209225+0.j  0.15403882+0.j  0.15172141+0.j]
#   [ 0.0551904 +0.j -0.10280741+0.j  0.07053759+0.j  0.10521177+0.j
#     0.10801417+0.j  0.12233795+0.j  0.11026284+0.j  0.10841349+0.j]
#   [ 0.07723492+0.j -0.14346973+0.j  0.09790949+0.j  0.14683067+0.j
#     0.15167648+0.j  0.17259504+0.j  0.15437234+0.j  0.15208209+0.j]
#   [ 0.05945795+0.j -0.1106429 +0.j  0.07598837+0.j  0.11325416+0.j
#     0.11604451+0.j  0.13145979+0.j  0.11851711+0.j  0.11666186+0.j]
#   [ 0.08318792+0.j -0.15439934+0.j  0.10545951+0.j  0.15804651+0.j
#     0.16297369+0.j  0.18547109+0.j  0.16594624+0.j  0.16364431+0.j]]
#
#  [[ 0.28744397+0.j  0.07510202+0.j -0.20668202+0.j  0.1064538 +0.j
#    -0.27346526+0.j  0.06231967+0.j  0.19569371+0.j -0.06040492+0.j]
#   [ 0.08604226+0.j  0.03335216+0.j -0.08699934+0.j  0.02727088+0.j
#    -0.07925033+0.j  0.03072465+0.j  0.08202314+0.j -0.03115125+0.j]
#   [-0.22572554+0.j -0.08787331+0.j  0.22912431+0.j -0.07144492+0.j
#     0.20786413+0.j -0.08081377+0.j -0.2163651 +0.j  0.08254165+0.j]
#   [ 0.07965637+0.j  0.03119278+0.j -0.081216  +0.j  0.02508629+0.j
#    -0.07328609+0.j  0.0288185 +0.j  0.0765341 +0.j -0.02920557+0.j]
#   [-0.22416863+0.j -0.08868052+0.j  0.23036032+0.j -0.07003028+0.j
#     0.20594453+0.j -0.08243114+0.j -0.21653926+0.j  0.08280456+0.j]
#   [ 0.079367  +0.j  0.03119378+0.j -0.08115429+0.j  0.02492876+0.j
#    -0.07298599+0.j  0.028866  +0.j  0.0764358 +0.j -0.02920632+0.j]
#   [ 0.20894297+0.j  0.08177164+0.j -0.21301434+0.j  0.0659096 +0.j
#    -0.19229193+0.j  0.07533869+0.j  0.20106186+0.j -0.07686343+0.j]
#   [-0.0735707 +0.j -0.02913827+0.j  0.07569614+0.j -0.02298809+0.j
#     0.06759336+0.j -0.02703975+0.j -0.07123954+0.j  0.02730217+0.j]]
#
#  [[ 0.08439841+0.j -0.11554654+0.j  0.0211644 +0.j -0.04760929+0.j
#    -0.08926376+0.j -0.11805272+0.j -0.01520063+0.j  0.10911649+0.j]
#   [-0.04555116+0.j  0.24268744+0.j  0.11170676+0.j  0.26337657+0.j
#     0.03655264+0.j  0.22723024+0.j -0.11686608+0.j -0.18519474+0.j]
#   [-0.01559274+0.j  0.08049277+0.j  0.03545288+0.j  0.08564709+0.j
#     0.01294805+0.j  0.07605307+0.j -0.03804656+0.j -0.06109195+0.j]
#   [-0.04276465+0.j  0.22587256+0.j  0.10347171+0.j  0.24455464+0.j
#     0.03446682+0.j  0.21158871+0.j -0.10834204+0.j -0.17248398+0.j]
#   [-0.01504333+0.j  0.07936136+0.j  0.0369486 +0.j  0.08650968+0.j
#     0.01197785+0.j  0.07398958+0.j -0.03814687+0.j -0.06093331+0.j]
#   [-0.04261146+0.j  0.22536804+0.j  0.10322946+0.j  0.24398855+0.j
#     0.0343454 +0.j  0.21115526+0.j -0.10815192+0.j -0.17204266+0.j]
#   [ 0.01415804+0.j -0.07444999+0.j -0.03326365+0.j -0.07974823+0.j
#    -0.01162657+0.j -0.070201  +0.j  0.03551462+0.j  0.05647937+0.j]
#   [ 0.03991911+0.j -0.20972298+0.j -0.0956652 +0.j -0.22660529+0.j
#    -0.03229165+0.j -0.19659338+0.j  0.10033044+0.j  0.16016104+0.j]]
#
#  [[ 0.35683604+0.j  0.01975982+0.j  0.37783222+0.j  0.012488  +0.j
#    -0.37431941+0.j -0.03114502+0.j -0.31974964+0.j  0.22303237+0.j]
#   [ 0.03689967+0.j  0.10973043+0.j  0.07420142+0.j -0.1364113 +0.j
#    -0.02337859+0.j  0.09996579+0.j -0.04808943+0.j  0.02158213+0.j]
#   [ 0.04939856+0.j  0.1703535 +0.j  0.10267169+0.j -0.21195527+0.j
#    -0.0271164 +0.j  0.1592105 +0.j -0.06809134+0.j  0.02956071+0.j]
#   [-0.03656589+0.j -0.11993255+0.j -0.07635926+0.j  0.14939416+0.j
#     0.02138354+0.j -0.1104097 +0.j  0.04935246+0.j -0.021244  +0.j]
#   [-0.04417981+0.j -0.14587718+0.j -0.09049348+0.j  0.18139065+0.j
#     0.02533344+0.j -0.13564033+0.j  0.05990264+0.j -0.02638708+0.j]
#   [ 0.03226299+0.j  0.10295099+0.j  0.06676205+0.j -0.12819181+0.j
#    -0.01934282+0.j  0.09444139+0.j -0.04310476+0.j  0.01873295+0.j]
#   [-0.04722743+0.j -0.15710123+0.j -0.096948  +0.j  0.19536384+0.j
#     0.02688204+0.j -0.14622453+0.j  0.06421579+0.j -0.02822288+0.j]
#   [ 0.03514873+0.j  0.11040429+0.j  0.07236498+0.j -0.13743996+0.j
#    -0.02136757+0.j  0.10105787+0.j -0.04668551+0.j  0.02041632+0.j]]
#
#  [[ 0.23409845+0.j -0.19369999+0.j  0.24554918+0.j  0.23487844+0.j
#    -0.25061199+0.j -0.21719619+0.j -0.20544253+0.j -0.03436819+0.j]
#   [ 0.00387899+0.j  0.12557129+0.j -0.04638014+0.j -0.10743002+0.j
#    -0.02039759+0.j  0.11800686+0.j  0.01345092+0.j  0.25821697+0.j]
#   [-0.0021526 +0.j -0.09569644+0.j  0.03428808+0.j  0.08207705+0.j
#     0.01529918+0.j -0.08854494+0.j -0.01129829+0.j -0.19681821+0.j]
#   [-0.00259148+0.j -0.13615406+0.j  0.05182322+0.j  0.11703174+0.j
#     0.01996764+0.j -0.12867088+0.j -0.01562284+0.j -0.27676875+0.j]
#   [ 0.00120259+0.j  0.08310144+0.j -0.03058139+0.j -0.07150355+0.j
#    -0.01232441+0.j  0.0773465 +0.j  0.01019461+0.j  0.16945547+0.j]
#   [ 0.0025525 +0.j  0.11716668+0.j -0.04421577+0.j -0.10060059+0.j
#    -0.01764371+0.j  0.11051573+0.j  0.01325614+0.j  0.23886936+0.j]
#   [ 0.0014313 +0.j  0.08925655+0.j -0.03267456+0.j -0.07675176+0.j
#    -0.01343971+0.j  0.08297739+0.j  0.01087005+0.j  0.18231371+0.j]
#   [ 0.00300947+0.j  0.12581074+0.j -0.04719852+0.j -0.10792929+0.j
#    -0.01931529+0.j  0.1185243 +0.j  0.01406996+0.j  0.25705504+0.j]]], shape=(8, 8, 8), dtype=complex128)

# %%
#Check the output of sum(K @ U @ rho @ U(dagger) @ K(dagger))  - suppose to be rho
rho_out_1 = calculate_rho_3(rho=rho, unitary_matrix=unitary_matrix, kraus_operators=kraus_operators_copy)

# %%
#Compare with rho
print(compilation_trace_fidelity(rho,rho_out_1))
# Out:
# tf.Tensor((0.9989167338873859+0j), shape=(), dtype=complex128)

# %%
print (rho_out_1)
# Out:
# tf.Tensor(
# [[ 9.97834642e-01+0.j -1.31236789e-05+0.j -1.11981909e-05+0.j
#    1.83755014e-06+0.j  1.18104742e-05+0.j -3.11568815e-06+0.j
#    1.18725175e-05+0.j -5.62235890e-06+0.j]
#  [-1.31236789e-05+0.j  6.84001993e-04+0.j  1.07258791e-04+0.j
#    1.94922799e-04+0.j  1.08092500e-05+0.j -6.25726395e-05+0.j
#    4.04727318e-05+0.j  3.46509628e-05+0.j]
#  [-1.11981909e-05+0.j  1.07258791e-04+0.j  1.82961211e-04+0.j
#    2.84188468e-04+0.j -1.99270000e-06+0.j -4.78850491e-05+0.j
#    2.60881376e-05+0.j -1.99930174e-05+0.j]
#  [ 1.83755014e-06+0.j  1.94922799e-04+0.j  2.84188468e-04+0.j
#    6.79737212e-04+0.j -5.42737764e-05+0.j -4.75801933e-05+0.j
#   -2.87206424e-05+0.j  4.91781969e-05+0.j]
#  [ 1.18104742e-05+0.j  1.08092500e-05+0.j -1.99270000e-06+0.j
#   -5.42737764e-05+0.j  2.65523270e-04+0.j  2.59729835e-04+0.j
#    1.50153649e-04+0.j -6.46928733e-05+0.j]
#  [-3.11568815e-06+0.j -6.25726395e-05+0.j -4.78850491e-05+0.j
#   -4.75801933e-05+0.j  2.59729835e-04+0.j  7.26050902e-04+0.j
#   -6.78056932e-05+0.j -2.13907154e-04+0.j]
#  [ 1.18725175e-05+0.j  4.04727318e-05+0.j  2.60881376e-05+0.j
#   -2.87206424e-05+0.j  1.50153649e-04+0.j -6.78056932e-05+0.j
#    2.85597801e-04+0.j  2.51333190e-04+0.j]
#  [-5.62235890e-06+0.j  3.46509628e-05+0.j -1.99930174e-05+0.j
#    4.91781969e-05+0.j -6.46928733e-05+0.j -2.13907154e-04+0.j
#    2.51333190e-04+0.j  6.90281400e-04+0.j]], shape=(8, 8), dtype=complex128)
