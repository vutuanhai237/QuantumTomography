# %%
from base import generator_gellmann
from base import generator_haar

def init_experiment(n, num_k):
    d = 2**n

    # Generate 6^n density matrices
    rho_list = generator_haar.generate_n_qubits_rho_haar(n)
    print(f"Generated {len(rho_list)} of {rho_list[0].shape} rho.")

    # Generate epsilon
    epsilon = generator_haar.random_unitary(d)
    print(f"Generated {epsilon.shape} epsilon.")

    # Generate K list
    kraus_operators = generator_haar.generate_kraus_operators(d, num_k)
    print(f"Generated {len(kraus_operators)} of {kraus_operators[0].shape} kraus operators.")
    return rho_list, epsilon, kraus_operators
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 55
#      52 # Example usage:
#      53 n_qubits = 1  # For example, a 2-qubit system
# ---> 55 kraus_operators = generate_full_rank_kraus_operators_from_random_unitary(n_qubits)
#      57 # Print the generated Kraus operators
#      58 print(kraus_operators.numpy())
#
# Cell In[9], line 29, in generate_full_rank_kraus_operators_from_random_unitary(n_qubits)
#      26 max_entangled_state = np.ones((dim, dim)) / np.sqrt(dim)
#      28 # Step 4: Construct the Choi matrix (Choi matrix = U ⊗ U^*)
# ---> 29 choi_matrix = np.kron(unitary, np.conj(unitary)) @ max_entangled_state
#      31 # Step 5: Perform Singular Value Decomposition (SVD)
#      32 U, S, V = np.linalg.svd(choi_matrix)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 4)
